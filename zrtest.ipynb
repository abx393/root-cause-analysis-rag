# %%
print("hey")
# Out:
# hey

# %%
# !pip install langchain langchain-core langchain-openai
# Out:
# Collecting langchain
#   Downloading langchain-1.0.8-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-core
#   Downloading langchain_core-1.0.7-py3-none-any.whl.metadata (3.6 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-1.0.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting langgraph<1.1.0,>=1.0.2 (from langchain)
#   Downloading langgraph-1.0.3-py3-none-any.whl.metadata (7.8 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Downloading pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
#      ---------------------------------------- 0.0/89.9 kB ? eta -:--:--
#      ---------------------------------------- 89.9/89.9 kB 5.0 MB/s eta 0:00:00
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core)
#   Downloading langsmith-0.4.43-py3-none-any.whl.metadata (14 kB)
# Collecting packaging<26.0.0,>=23.2.0 (from langchain-core)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-core) (6.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-core) (8.2.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-core) (4.13.0)
# Collecting openai<3.0.0,>=1.109.1 (from langchain-openai)
#   Downloading openai-2.8.1-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.12.0-cp310-cp310-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (2.3)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_prebuilt-1.0.4-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading xxhash-3.6.0-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Collecting httpx<1,>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.3.45->langchain-core)
#   Downloading orjson-3.11.4-cp310-cp310-win_amd64.whl.metadata (42 kB)
#      ---------------------------------------- 0.0/42.9 kB ? eta -:--:--
#      ---------------------------------------- 42.9/42.9 kB 2.2 MB/s eta 0:00:00
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.3)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core)
#   Downloading zstandard-0.25.0-cp310-cp310-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (3.6.2)
# Collecting distro<2,>=1.7.0 (from openai<3.0.0,>=1.109.1->langchain-openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=1.109.1->langchain-openai)
#   Downloading jiter-0.12.0-cp310-cp310-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.41.5-cp310-cp310-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-extensions<5.0.0,>=4.7.0 (from langchain-core)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2024.11.6)
# Requirement already satisfied: idna>=2.8 in c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.109.1->langchain-openai) (3.4)
# Requirement already satisfied: certifi in c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2022.12.7)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading ormsgpack-1.12.0-cp310-cp310-win_amd64.whl.metadata (1.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.0.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.26.14)
# Requirement already satisfied: colorama in c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai) (0.4.6)
# Downloading langchain-1.0.8-py3-none-any.whl (93 kB)
#    ---------------------------------------- 0.0/93.7 kB ? eta -:--:--
#    ---------------------------------------- 93.7/93.7 kB ? eta 0:00:00
# Downloading langchain_core-1.0.7-py3-none-any.whl (472 kB)
#    ---------------------------------------- 0.0/473.0 kB ? eta -:--:--
#    ------------------------ --------------- 286.7/473.0 kB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 473.0/473.0 kB 5.9 MB/s eta 0:00:00
# Downloading langchain_openai-1.0.3-py3-none-any.whl (82 kB)
#    ---------------------------------------- 0.0/82.5 kB ? eta -:--:--
#    ---------------------------------------- 82.5/82.5 kB ? eta 0:00:00
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph-1.0.3-py3-none-any.whl (156 kB)
#    ---------------------------------------- 0.0/156.8 kB ? eta -:--:--
#    ---------------------------------------  153.6/156.8 kB 9.0 MB/s eta 0:00:01
#    ---------------------------------------- 156.8/156.8 kB 4.7 MB/s eta 0:00:00
# Downloading langsmith-0.4.43-py3-none-any.whl (410 kB)
#    ---------------------------------------- 0.0/410.2 kB ? eta -:--:--
#    --------------------- ------------------ 225.3/410.2 kB 6.9 MB/s eta 0:00:01
#    ------------------------------------- -- 389.1/410.2 kB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 410.2/410.2 kB 3.7 MB/s eta 0:00:00
# Downloading openai-2.8.1-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    -------- ------------------------------- 0.2/1.0 MB 6.3 MB/s eta 0:00:01
#    --------------- ------------------------ 0.4/1.0 MB 5.0 MB/s eta 0:00:01
#    ------------------------------ --------- 0.8/1.0 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 6.5 MB/s eta 0:00:00
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.5 kB ? eta -:--:--
#    ---------------------------------------- 66.5/66.5 kB ? eta 0:00:00
# Downloading pydantic-2.12.4-py3-none-any.whl (463 kB)
#    ---------------------------------------- 0.0/463.4 kB ? eta -:--:--
#    ---------------------------- ---------- 337.9/463.4 kB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 463.4/463.4 kB 5.8 MB/s eta 0:00:00
# Downloading pydantic_core-2.41.5-cp310-cp310-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/2.0 MB 9.6 MB/s eta 0:00:01
#    ------------ --------------------------- 0.6/2.0 MB 10.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.2/2.0 MB 10.7 MB/s eta 0:00:01
#    ------------------------------ --------- 1.5/2.0 MB 9.8 MB/s eta 0:00:01
#    -------------------------------------- - 2.0/2.0 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 8.6 MB/s eta 0:00:00
# Downloading tiktoken-0.12.0-cp310-cp310-win_amd64.whl (879 kB)
#    ---------------------------------------- 0.0/879.4 kB ? eta -:--:--
#    ----------------------- --------------- 532.5/879.4 kB 16.8 MB/s eta 0:00:01
#    --------------------------------------- 879.4/879.4 kB 11.1 MB/s eta 0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/44.6 kB ? eta -:--:--
#    ---------------------------------------- 44.6/44.6 kB ? eta 0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jiter-0.12.0-cp310-cp310-win_amd64.whl (204 kB)
#    ---------------------------------------- 0.0/204.8 kB ? eta -:--:--
#    ---------------------------------------- 204.8/204.8 kB 6.3 MB/s eta 0:00:00
# Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
#    ---------------------------------------- 0.0/46.2 kB ? eta -:--:--
#    ---------------------------------------- 46.2/46.2 kB ? eta 0:00:00
# Downloading langgraph_prebuilt-1.0.4-py3-none-any.whl (34 kB)
# Downloading langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.8 kB ? eta -:--:--
#    ---------------------------------------- 56.8/56.8 kB ? eta 0:00:00
# Downloading orjson-3.11.4-cp310-cp310-win_amd64.whl (131 kB)
#    ---------------------------------------- 0.0/131.6 kB ? eta -:--:--
#    ---------------------------------------- 131.6/131.6 kB 8.1 MB/s eta 0:00:00
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading xxhash-3.6.0-cp310-cp310-win_amd64.whl (31 kB)
# Downloading zstandard-0.25.0-cp310-cp310-win_amd64.whl (506 kB)
#    ---------------------------------------- 0.0/506.1 kB ? eta -:--:--
#    ------------------------------ --------- 389.1/506.1 kB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 506.1/506.1 kB 8.0 MB/s eta 0:00:00
# Downloading ormsgpack-1.12.0-cp310-cp310-win_amd64.whl (112 kB)
#    ---------------------------------------- 0.0/112.7 kB ? eta -:--:--
#    ---------------------------------------- 112.7/112.7 kB 6.8 MB/s eta 0:00:00
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: zstandard, xxhash, typing-extensions, packaging, ormsgpack, orjson, jsonpatch, jiter, h11, distro, annotated-types, typing-inspection, tiktoken, requests-toolbelt, pydantic-core, httpcore, pydantic, httpx, openai, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langchain-openai, langgraph-prebuilt, langgraph, langchain
#   Attempting uninstall: xxhash
#     Found existing installation: xxhash 3.4.1
#     Uninstalling xxhash-3.4.1:
#       Successfully uninstalled xxhash-3.4.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.13.0
#     Uninstalling typing_extensions-4.13.0:
#       Successfully uninstalled typing_extensions-4.13.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.0
#     Uninstalling packaging-23.0:
#       Successfully uninstalled packaging-23.0
#   Attempting uninstall: orjson
#     Found existing installation: orjson 3.9.10
#     Uninstalling orjson-3.9.10:
#       Successfully uninstalled orjson-3.9.10
#   Attempting uninstall: openai
#     Found existing installation: openai 0.26.5
#     Uninstalling openai-0.26.5:
#       Successfully uninstalled openai-0.26.5
# Successfully installed annotated-types-0.7.0 distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 jiter-0.12.0 jsonpatch-1.33 langchain-1.0.8 langchain-core-1.0.7 langchain-openai-1.0.3 langgraph-1.0.3 langgraph-checkpoint-3.0.1 langgraph-prebuilt-1.0.4 langgraph-sdk-0.2.9 langsmith-0.4.43 openai-2.8.1 orjson-3.11.4 ormsgpack-1.12.0 packaging-25.0 pydantic-2.12.4 pydantic-core-2.41.5 requests-toolbelt-1.0.0 tiktoken-0.12.0 typing-extensions-4.15.0 typing-inspection-0.4.2 xxhash-3.6.0 zstandard-0.25.0
# WARNING: Ignoring invalid distribution -ip (c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\zayaa\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\zayaa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4o-mini", temperature=0)

prompt = PromptTemplate.from_template("Say hello to {name}!")
final_prompt = prompt.format(name="Bob")
response = model.invoke(final_prompt)
print("LLM Response: ", response.content)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[7], line 4
#       1 from langchain_core.prompts import PromptTemplate
#       2 from langchain_openai import ChatOpenAI
# ----> 4 model = ChatOpenAI(model="gpt-4o-mini", temperature=0)
#       6 prompt = PromptTemplate.from_template("Say hello to {name}!")
#       7 final_prompt = prompt.format(name="Bob")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\langchain_core\load\serializable.py:116, in Serializable.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     115     """"""  # noqa: D419  # Intentional blank docstring
# --> 116     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\langchain_openai\chat_models\base.py:948, in BaseChatOpenAI.validate_environment(self)
#     938         self.http_async_client = httpx.AsyncClient(
#     939             proxy=self.openai_proxy, verify=global_ssl_context
#     940         )
#     941     async_specific = {
#     942         "http_client": self.http_async_client
#     943         or _get_default_async_httpx_client(
#    (...)
#     946         "api_key": async_api_key_value,
#     947     }
# --> 948     self.root_async_client = openai.AsyncOpenAI(
#     949         **client_params,
#     950         **async_specific,  # type: ignore[arg-type]
#     951     )
#     952     self.async_client = self.root_async_client.chat.completions
#     953 return self
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\openai\_client.py:488, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     486     api_key = os.environ.get("OPENAI_API_KEY")
#     487 if api_key is None:
# --> 488     raise OpenAIError(
#     489         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     490     )
#     491 if callable(api_key):
#     492     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
# making request from the dag to find the issue within the dag.
